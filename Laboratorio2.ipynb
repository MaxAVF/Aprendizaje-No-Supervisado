# %% [markdown]
# # Aprendizaje no supervisado: Sistemas de recomendacion ́
# #### Maximiliano Vides

# %% [markdown]
# ### Objetivo
# En este practico tendran que integrar en la notebook el sistema de recomendacion basado en contenido que se propone en http://nbviewer.jupyter.org/github/khanhnamle1994/movielens/blob/master/Content_Based_and_Collaborative_Filtering_Models.ipynb.

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# # Dataset

# %% [markdown]
# Usaremos un dataset extraido de https://arxiv.org/ que consiste en datos de 10000 papers de la sección de matemática de dicha página que fueron descargados utilizando la Arxiv API (https://arxiv.org/help/api/index).
# De este dataset guardado en formato Json, contiene metadatos de cada artículo, como titulo, resumen, autores, link del artículo, distitnos tags entre otros, de los cuales vamos a utilizar solamente los datos correspondientes a los resúmenes y titulos para intentar hacer un clustering de los papers en relación a las palabras en común.

# %% [markdown]
# Cargamos el dataset, extraemos los datos de titulos y resúmenes de los articulos, como en el laboratorio anterior,y utilizamos TfidfVectorizer para representarlos.

# %%
import json
with open('data.json') as f:
    datamath = json.load(f,encoding="UTF-8")

# %%
titles = [datamath["entries"][i]["title"] for i in range(len(datamath["entries"]))]
len(titles)
# Out:
# 10000

# %%
summaries = [datamath["entries"][i]["summary"] for i in range(len(datamath["entries"]))]
len(summaries)
# Out:
# 10000

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(summaries)
tfidf_matrix.shape
# Out:
# (10000, 349232)

# %% [markdown]
# # Recomendación basada en contenido

# %% [markdown]
# Para implementar el recomendador basado en contenido utilizaremos la similaridad del coseno entre los resumenes de los artículos.

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim[:4, :4]
# Out:
# array([[1.        , 0.00753694, 0.04343791, 0.27474781],
#        [0.00753694, 1.        , 0.00369972, 0.005619  ],
#        [0.04343791, 0.00369972, 1.        , 0.07211436],
#        [0.27474781, 0.005619  , 0.07211436, 1.        ]])

# %% [markdown]
# A continuación, veremos los articulos mas "similares" para asegurarnos que funciona bien.

# %%
for i in range(1000):
 for j in range(1000):
  if j>i :
   if cosine_sim[i, j]>0.5:
    print(i,titles[i])
    print(j,titles[j])
    print("cosine similarity: %r" %cosine_sim[i, j])
    print('=' * 60)
# Out:
# 7 Right Bousfield Localization and Operadic Algebras
# 949 Right Bousfield Localization and Eilenberg-Moore Categories
# cosine similarity: 0.5471909482710594
# ============================================================
# 292 Green's function of the problem of bounded solutions in the case of a
#   block triangular coefficient
# 987 Computation of Green's function of the bounded solutions problem
# cosine similarity: 0.5631867992305797
# ============================================================
# 303 Classification of equivariant vector bundles over real projective plane
# 304 Classification of equivariant vector bundles over two-torus
# cosine similarity: 0.5306357243588083
# ============================================================
# 328 Ore's theorem for cyclic subfactor planar algebras and applications
# 739 Ore's theorem on cyclic subfactor planar algebras and beyond
# cosine similarity: 0.5272474922502542
# ============================================================
# 370 An Introduction to Hilbert Module Approach to Multivariable Operator
#   Theory
# 371 Applications of Hilbert Module Approach to Multivariable Operator Theory
# cosine similarity: 0.7079576076445369
# ============================================================
# 557 Functions of perturbed operators
# 560 Operator Hölder--Zygmund functions
# cosine similarity: 0.5116142881205226
# ============================================================
# 563 Functions of normal operators under perturbations
# 571 Functions of perturbed normal operators
# cosine similarity: 0.9871700575222931
# ============================================================
# 569 Functions of perturbed noncommuting self-adjoint operators
# 573 Triple operator integrals in Schatten--von Neumann norms and functions
#   of perturbed noncommuting operators
# cosine similarity: 0.5834192620924574
# ============================================================
# 576 Operator Lipschitz Functions
# 580 Operator Lipschitz functions (English translation)
# cosine similarity: 0.8328828072284618
# ============================================================
# 578 Krein's trace formula for unitary operators and operator Lipschitz
#   functions
# 581 Krein's trace formula for unitary operators and operator Lipschitz
#   functions (English translation)
# cosine similarity: 0.7112949001091569
# ============================================================
# 582 A trace formula for functions of contractions and analytic operator
#   Lipschitz functions
# 583 Analytic operator Lipschitz functions in the disk and a trace formula
#   for functions of contractions
# cosine similarity: 0.5065584367901688
# ============================================================
# 606 Moduli space actions on the Hochschild Co-Chains of a Frobenius algebra
#   I: Cell Operads
# 607 Moduli space actions on the Hochschild co-chains of a Frobenius algebra
#   II: Correlators
# cosine similarity: 0.6605162451451632
# ============================================================
# 621 HPD-invariance of the Tate conjecture
# 624 HPD-invariance of the Tate, Beilinson and Parshin conjectures
# cosine similarity: 0.5529996533030817
# ============================================================
# 720 A class of Littlewood polynomials that are not $L^α$-flat
# 760 The Rudin-Shapiro polynomials and The Fekete polynomials are not
#   $L^α$-flat
# cosine similarity: 0.5372692295364111
# ============================================================
# 744 Idempotent and tropical mathematics and problems of mathematical physics
#   (Volume II)
# 745 Idempotent and tropical mathematics and problems of mathematical physics
#   (Volume I)
# cosine similarity: 0.9999999999999994
# ============================================================
# 906 A triangulated category without models
# 907 Triangulated categories without models
# cosine similarity: 0.6061237922815051
# ============================================================

# %% [markdown]
# Observamos que entre los articulos mas similares aparecen versiones del mismo paper, traducciones (que tienen el mismo resumen en inglés) y volumenes del mismo artículo, por lo que parece que funciona bastante bien.

# %% [markdown]
# Procedemos a definir la función "recommendations", cuya entrada sera el titulo de un paper y la salida serán los 20 papers más similares.

# %%
from sklearn.metrics.pairwise import cosine_similarity

Titles = pd.Series(titles)
indices = pd.Series(summaries, index=titles)


def recommendations(title):
    idx = titles.index(title)
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:21]
    paper_indices = [i[0] for i in sim_scores]
    sim_scores=[i[1] for i in sim_scores]
    df=pd.DataFrame({'Title': Titles.iloc[paper_indices],'Cosine Similiarity': sim_scores})
    print(title)
    return df

# %% [markdown]
# A continuación veremos algunos ejemplos para evaluar el funcionamiento del recomendador.

# %%
x=5563 
recommendations(titles[x])
# Out:
# Applications of Bimatrices to some Fuzzy and Neutrosophic Models
#                                                                                                     Title  \
# 5477    Basic Neutrosophic Algebraic Structures and their Application to Fuzzy\n  and Neutrosophic Models
# 5546                                                                           Introduction to Bimatrices
# 5581                                 Fuzzy and Neutrosophic Analysis of Periyar's views on Untouchability
# 5590                         Introduction to n-adaptive fuzzy models to analyze public opinion on\n  AIDS
# 6441                                    Super Fuzzy Matrices and Super Fuzzy Models for Social Scientists
# 5697                                Elementary fuzzy matrix theory and fuzzy models for social scientists
# 5403                                                                            Smarandache Fuzzy Algebra
# 6278                Mathematical Analysis of the Problems faced by the People With\n  Disabilities (PWDs)
# 5988  Reservation for Other Backward Classes in Indian Central Government\n  Institutions like IITs, I...
# 6528                                                          New classes of Neutrosophic Linear Algebras
# 5915                                                      n-Linear Algebra of type I and its applications
# 5415                                                 Fuzzy Cognitive Maps and Neutrosophic Cognitive Maps
# 2322                             A study of the interrelation between fuzzy topological systems and logic
# 5597                    Some Neutrosophic Algebraic Structures and Neutrosophic N-Algebraic\n  Structures
# 5602                                                        Smarandache Neutrosophic Algebraic Structures
# 5667                  Vedic Mathematics: 'Vedic' or 'Mathematics' -- A Fuzzy and Neutrosophic\n  Analysis
# 6187                                                                  Fuzzy Linguistic Topological Spaces
# 5642                    Fuzzy Interval Matrices, Neutrosophic Interval Matrices and their\n  Applications
# 5549                                               Fuzzy and Neutrosophic Analysis of Women with HIV/AIDS
# 5969                                                            Superbimatrices and their generalizations
#
#       Cosine Similiarity
# 5477            0.270344
# 5546            0.221517
# 5581            0.218890
# 5590            0.211508
# 6441            0.208041
# 5697            0.187087
# 5403            0.181675
# 6278            0.179262
# 5988            0.173588
# 6528            0.165790
# 5915            0.161046
# 5415            0.160263
# 2322            0.158511
# 5597            0.155009
# 5602            0.152701
# 5667            0.151324
# 6187            0.151246
# 5642            0.151225
# 5549            0.140416
# 5969            0.139868

# %%
recommendations(titles[5305])
# Out:
# The cardinality of the set of real numbers
#                                                                                                     Title  \
# 5438                                                                     Countability of the Real Numbers
# 5440                                                    Remarks on Cantor's diagonalization proof of 1891
# 5465                                                     A severe inconsistency of transfinite set theory
# 5823  The property of the set of the real numbers generated by a\n  Gelfond-Schneider operator and the...
# 5896                                                       The Continuum is Countable: Infinity is Unique
# 6033                                                                                 Cantor versus Cantor
# 5439                                                                              The Meaning of Infinity
# 5383                                                                         On Cantor's important proofs
# 4504                                                                   Continuous Maps on Aronszajn Trees
# 3005                                                                   A new approach to the real numbers
# 7101  Hyperreal delta functions as a new general tool for modeling physical\n  states with infinitely ...
# 3281                                                                                Origami constructions
# 5292                                                    On the cardinality of the set of the real numbers
# 3217                                                                             The Eudoxus Real Numbers
# 3182  Hypothesis of the Functional Semantic Constructions and Mathematics in\n  the Functional Semanti...
# 5156                                       The n-th smallest term for any finite sequence of real numbers
# 3816                                       A Purely Algebraic Proof of the Fundamental Theorem of Algebra
# 5376                                                                    Infinite sets are non-denumerable
# 6522                                      Addressing mathematical inconsistency: Cantor and Godel refuted
# 4389                                                        A result related to the problem CN of Fremlin
#
#       Cosine Similiarity
# 5438            0.295263
# 5440            0.200049
# 5465            0.196416
# 5823            0.192680
# 5896            0.192603
# 6033            0.148338
# 5439            0.137424
# 5383            0.132368
# 4504            0.132241
# 3005            0.130614
# 7101            0.125086
# 3281            0.121492
# 5292            0.113671
# 3217            0.109531
# 3182            0.105996
# 5156            0.105756
# 3816            0.101703
# 5376            0.101251
# 6522            0.099605
# 4389            0.095101

# %%
recommendations(titles[7087])
# Out:
# A Note on the Classification of Permutation Matrix
#                                                                                                     Title  \
# 5558                                                     Tensor Permutation Matrices in Finite Dimensions
# 8650                                          Pseudospectra of Isospectrally Reduced Matrices and Systems
# 7704                                    An algebraic approach to representations of the permutation group
# 6703                                            The Neighbor Matrix: Generalizing the Degree Distribution
# 4028     Nonnegative Factorization of a Data Matrix as a Motivational Example for\n  Basic Linear Algebra
# 4049                              A Short and Elementary Proof of the Two-sidedness of the Matrix-Inverse
# 7119                                           A Fast Algorithm to Calculate Power Sum of Natural Numbers
# 5479      A matrix-based proof of the quaternion representation theorem for\n  four-dimensional rotations
# 515                     A Note on the Reduction Formulas for Some Systems of Linear Operator\n  Equations
# 5048                                                      Primitive permutation groups containing a cycle
# 8195  Necessary And Sufficient Conditions For Existence of the LU\n  Factorization of an Arbitrary Matrix
# 5472                                                         An Explicit Formula for the Matrix Logarithm
# 6222                                                      Kronecker Square Roots and The Block vec Matrix
# 2844                                      Matrix algebra of sets and variants of decomposition complexity
# 6095                                                                   On the tensor Permutation Matrices
# 6389                               Companion Matrices and Their Relations to Toeplitz and Hankel Matrices
# 555                                Analytic approximation of matrix functions and dual extremal functions
# 6036                                                                        The Matrix of Linear Mappings
# 4637                                                                      Infinite powers and Cohen reals
# 8056           Matrix analogs of B-functions and Plancherel formula for Berezin kernel\n  representations
#
#       Cosine Similiarity
# 5558            0.271487
# 8650            0.131143
# 7704            0.118978
# 6703            0.114383
# 4028            0.111425
# 4049            0.111120
# 7119            0.108370
# 5479            0.107540
# 515             0.107010
# 5048            0.102744
# 8195            0.101505
# 5472            0.091056
# 6222            0.089811
# 2844            0.085511
# 6095            0.085135
# 6389            0.079929
# 555             0.079563
# 6036            0.078591
# 4637            0.077819
# 8056            0.074012

# %%
recommendations(titles[1560])
# Out:
# Generalizations of Triangle Inequalities to Spherical and Hyperbolic
#   Geometry
#                                                                                                     Title  \
# 1529                                        On the works of Euler and his followers on spherical geometry
# 1527                                                              On Lobachevsky's trigonometric formulae
# 7085                                                          New Proofs of Classical Triangle Inequality
# 2355                                                                         Ceva's triangle inequalities
# 1531                                         Euclidean plane and its relatives; a minimalist introduction
# 5831                                                                      A little noticed right triangle
# 6039  Smarandache's Cevian Triangle Theorem in The Einstein Relativistic\n  Velocity Model of Hyperbol...
# 3971                                              Revisiting the quadrisection problem of Jacob Bernoulli
# 1517                                                             Generalization of the Apollonius Circles
# 7054                                                           Mercer's inequality for h-convex functions
# 7762                                          Continuity of the Volume of Simplices in Classical Geometry
# 6295                                 A generalized Young inequality and some new results on fractal space
# 5929                                      On a class of entire functions, all the zeros of which are real
# 7112                                     A Proof of the Riemann Hypothesis Through the Nicolas Inequality
# 4071                                                                        When a triangle is isosceles?
# 6962                                           The Second Postulate of Euclid and the Hyperbolic Geometry
# 5981                                                                    A new inequality involving primes
# 6554               Generalizations of Holder's and some related integral inequalities on\n  fractal space
# 4027                      On the impossibility of constructing a triangle given its internal\n  bisectors
# 2839                                                                  Rational Angled Hyperbolic Polygons
#
#       Cosine Similiarity
# 1529            0.148198
# 1527            0.107013
# 7085            0.103398
# 2355            0.100967
# 1531            0.087734
# 5831            0.081389
# 6039            0.081108
# 3971            0.077686
# 1517            0.075631
# 7054            0.075124
# 7762            0.070345
# 6295            0.069295
# 5929            0.068147
# 7112            0.066885
# 4071            0.066050
# 6962            0.063461
# 5981            0.062775
# 6554            0.061371
# 4027            0.060932
# 2839            0.060875

# %% [markdown]
# En estos ejemplos podemos ver que parece haber una buena performance en las recomendaciones de los artículos. Si bien no todas las recomendaciones parecen ser pertinentes, debido que algunas recomendaciones tienen un score de similarity bastante bajo, en general parece funcionar bastante bien.
